# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# NAVEEN KUMAR M

# %% [markdown]
# Data scientist

# %% [markdown]
# *I am interested in data science because I would love to contribute affordable and quality healthcare in the future

# %% [markdown]
# ### Printing the text

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ***
# - Tools
# |S No.|Tools|
# |----|----|
# |1|python|
# |2|R|
# ***
